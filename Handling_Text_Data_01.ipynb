# %% [markdown]
# # **Handling Text Data**

# %% [markdown]
# ###  **Aim:** Program to perform stemming, lemmatization, and find synonyms and antonyms of words.

# %%
# Importing the required libraries
import pandas as pd
import nltk
import re
import string
import requests
from bs4 import BeautifulSoup
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer,WordNetLemmatizer
from nltk.corpus import wordnet,stopwords
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Scraping a paragraph from wikipedia
url='https://en.wikipedia.org/wiki/Natural_disaster'
r=requests.get(url)
soup=BeautifulSoup(r.content,'html.parser')
content=soup.find('div',{'id':'mw-content-text'})
paragraphs=content.find_all('p')
with open('natural_disaster.txt','w') as file:
  for paragraph in paragraphs:
    file.write(paragraph.get_text())

# %%
# Preprocessing the text
def preprocess(text):
  # Converting to lower case
  text=text.lower()
  # Removing digits and special characters
  text=re.sub(r'[^\w\s]','',text)
  text=re.sub(r'[^a-zA-Z\s]','',text)
  text=re.sub(r'\d+','',text)
  # Tokenizing the words
  words=text.split()
  stop_words=set(stopwords.words('english'))
  filtered_words=[word for word in words if word not in stop_words]
  preprocessed_text=' '.join(filtered_words)
  return preprocessed_text

# %%
# Applying the function to the scraped text
with open('natural_disaster.txt','r') as file:
  text=file.read()
  preprocessed_text=preprocess(text)

# %%
# Saving the preprocessed text
with open('preprocessed_text.txt','w') as file:
  file.write(preprocessed_text)

# %%
# Displaying the preprocessed text
with open('preprocessed_text.txt','r') as file:
  text=file.read()
  print(text)
# Out:
# natural disaster highly harmful impact society community following natural hazard event examples natural hazard events include flooding drought earthquake tropical cyclone lightning tsunami volcanic activity wildfire natural disaster cause loss life damage property typically leaves economic damage wake severity damage depends affected populations resilience infrastructure available scholars saying term natural disaster unsuitable abandoned instead simpler term disaster could used also specifying category type hazard disaster result natural humanmade hazard impacting vulnerable community combination hazard along exposure vulnerable society results disaster modern times divide natural humanmade humanaccelerated disasters quite difficult draw human choices activities like architecture fire resource management climate change potentially play role causing natural disasters fact term natural disaster called misnomer already natural disasters aggravated inadequate building norms marginalization people inequities overexploitation resources extreme urban sprawl climate change rapid growth worlds population increased concentration often hazardous environments escalated frequency severity disasters extreme climates tropics unstable landforms coupled deforestation unplanned growth proliferation nonengineered constructions create vulnerable interfaces populated areas disasterprone natural spaces developing countries suffer chronic natural disasters often ineffective communication systems combined insufficient support disaster prevention management adverse event rise level disaster occurs area without vulnerable population vulnerable population experienced disaster community take many years repair repair period lead vulnerability disastrous consequences natural disaster also affect mental health affected communities often leading posttraumatic symptoms increased emotional experiences supported collective processing leading resilience increased community engagement natural disaster highly harmful impact society community following natural hazard event term disaster defined follows disasters serious disruptions functioning community exceed capacity cope using resources disasters caused natural manmade technological hazards well various factors influence exposure vulnerability community us federal emergency management agency fema explains relationship natural disasters natural hazards follows natural hazards natural disasters related natural hazard threat event likely negative impact natural disaster negative impact following actual occurrence natural hazard event significantly harms community example distinction natural hazard disaster earthquake hazard caused san francisco earthquake disaster natural hazard natural phenomenon might negative effect humans animals environment natural hazard events classified two broad categories geophysical biological natural hazards provoked affected anthropogenic processes eg landuse change drainage construction natural hazards included national risk index fema avalanche coastal flooding cold wave drought earthquake hail heat wave tropical cyclone ice storm landslide lightning riverine flooding strong wind tornado tsunami volcanic activity wildfire winter weather addition also tornados dust storms term natural disaster called misnomer already disaster result natural hazard impacting vulnerable community disasters avoided earthquakes droughts floods storms events lead disasters human action inaction poor land policy planning deregulation create worse conditions often involve development activities ignore fail reduce disaster risks nature alone blamed disasters even disasters result failures development disasters also result failure societies prepare examples failures include inadequate building norms marginalization people inequities overexploitation resources extreme urban sprawl climate change defining disasters solely natural events serious implications comes understanding causes disaster distribution poli ...

# %%
# Reading the processed text file
with open('preprocessed_text.txt','r') as file:
  text=file.read()

# Tokenizing the text into words and keep only unique words
unique_words= set(word_tokenize(text))

# Initiliazing stemmer and lemmatizer
stemmer=PorterStemmer()
lemmatizer=WordNetLemmatizer()

# To find synonyms and antonyms of a word
def synonyms_antonyms(words):
  synonyms=set()
  antonyms=set()
  for syn in wordnet.synsets(word):
    for lemma in syn.lemmas():
      synonymns.add(lemma.name())
      if lemma.antonyms():
        antonyms.add(lemma.antonyms()[0].name())
  return synonyms,antonyms

# %%
# Creating a df to display the results
word_list = []
lemmatized_list = []
stemmed_list = []
antonyms_list = []
synonyms_list = []
# Process each word
for word in unique_words:
    # Lemmatize the word
    lemmatized_word = lemmatizer.lemmatize(word)

    # Stem the word
    stemmed_word = stemmer.stem(word)

    # Get synonyms and antonyms of the word
    synonyms, antonyms = get_synonyms_antonyms(word)

    # Append data to lists
    word_list.append(word)
    lemmatized_list.append(lemmatized_word)
    stemmed_list.append(stemmed_word)
    antonyms_list.append(antonyms)
    synonyms_list.append(synonyms)

# Create DataFrame
df = pd.DataFrame({
    'Word': word_list,
    'Lemmatized': lemmatized_list,
    'Stemmed': stemmed_list,
    'Antonyms': antonyms_list,
    'Synonyms': synonyms_list
})

# %%
# Displaying the dataframe
df.head(20)
# Out:
#              Word     Lemmatized       Stemmed                Antonyms  \
# 0           could          could         could                      {}
# 1         touches          touch         touch                      {}
# 2        manifest       manifest      manifest                      {}
# 3         driving        driving         drive               {attract}
# 4      sufficient     sufficient       suffici          {insufficient}
# 5        citizens        citizen       citizen            {noncitizen}
# 6   psychological  psychological     psycholog                      {}
# 7         infants         infant        infant                      {}
# 8            cope           cope          cope                      {}
# 9          effect         effect        effect                      {}
# 10          often          often         often  {rarely, infrequently}
# 11    explosivity    explosivity        explos                      {}
# 12         closed         closed         close                  {open}
# 13        leaking        leaking          leak                      {}
# 14   coordination   coordination       coordin        {incoordination}
# 15           used           used           use               {misused}
# 16       disaster       disaster        disast                      {}
# 17         mental         mental        mental              {physical}
# 18   thunderstorm   thunderstorm  thunderstorm                      {}
# 19         storms          storm         storm                      {}
#
#                                              Synonyms
# 0                                                  {}
# 1   {skin_senses, meet, disturb, touch_modality, t...
# 2   {attest, evidence, evident, demonstrate, certi...
# 3   {tug, repel, driving, get, impulsive, take, dr...
# 4                                        {sufficient}
# 5                                           {citizen}
# 6                                     {psychological}
# 7                                {infant, babe, baby}
# 8   {make_out, make_do, cope, coping, manage, get_...
# 9   {outcome, consequence, upshot, essence, burden...
# 10  {often, frequently, oft, much, ofttimes, often...
# 11                                                 {}
# 12  {unsympathetic, fill_up, close_down, closed_in...
# 13                                   {leak, leak_out}
# 14                                     {coordination}
# 15  {habituate, apply, utilize, victimized, ill-us...
# 16  {tragedy, disaster, cataclysm, catastrophe, ca...
# 17                                   {genial, mental}
# 18   {electric_storm, electrical_storm, thunderstorm}
# 19  {tempest, surprise, ramp, storm, violent_storm...

# %% [markdown]
# ## **Conclusion**
# The paragraph retrieved from Wikipedia underwent preprocessing. During this process, the words were transformed into their root forms, and their respective synonyms and antonyms were identified. These results were then presented using a DataFrame
